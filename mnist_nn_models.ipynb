# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.optimizers import SGD
from keras.losses import categorical_crossentropy


# Load and preprocess data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], -1) / 255
x_test = x_test.reshape(x_test.shape[0], -1) / 255

# Feature extraction
def quadrant_average(image):
  rows, cols = 28, 28
  q1 = np.mean(image[:rows // 2 * cols // 2])
  q2 = np.mean(image[rows // 2 * cols // 2: rows // 2 * cols])
  q3 = np.mean(image[rows // 2 * cols: rows // 2 * cols + cols // 2])
  q4 = np.mean(image[rows // 2 * cols + cols // 2:])
  return np.array([q1, q2, q3, q4])


x_train = np.array([quadrant_average(img) for img in x_train])
x_test = np.array([quadrant_average(img) for img in x_test])

# Split training data into training and validation sets
split = int(0.2 * x_train.shape[0])
x_val = x_train[:split]
y_val = y_train[:split]
x_train = x_train[split:]
y_train = y_train[split:]

max_val = np.max(y_train)
y_train = np.minimum(y_train, num_classes - 1)
y_val = np.minimum(y_val, num_classes - 1)
y_test = np.minimum(y_test, num_classes - 1)

# Convert labels to categorical variables
num_classes = 3
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)
y_test = to_categorical(y_test, num_classes)

# Define and train models with different architectures
models = []
architectures = [
    (16,),  # 1 layer, 16 nodes
    (64,),  # 1 layer, 64 nodes
    (128,),  # 1 layer, 128 nodes
    (128, 16),  # 2 layers, 128, 16 nodes
    (128, 64),  # 2 layers, 128, 64 nodes
]
for nodes in architectures:
  model = Sequential()
  model.add(Dense(nodes[0], activation='relu', input_dim=4))
  model.add(Dense(num_classes, activation='softmax'))
  model.compile(loss=categorical_crossentropy, optimizer=SGD(lr=0.0001), metrics=['accuracy'])
  model.fit(x_train, y_train, epochs=30, batch_size=16, validation_data=(x_val, y_val))
  models.append(model)

# Evaluate and compare models (training/validation loss and accuracy)
for i, model in enumerate(models):
  loss, accuracy = model.evaluate(x_train, y_train)
  val_loss, val_acc = model.evaluate(x_val, y_val)
  print(f"Model {i+1} (layers: {len(architectures[i])}, nodes: {architectures[i]})")
  print(f"- Training Loss: {loss:.4f}, Training Accuracy: {accuracy:.4f}")
  print(f"- Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}")
  print("")

best_model = models[4]
test_loss, test_acc = best_model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

#The training loss and validation loss decrease as the layers and nodes increase but it does change around when ran multiple times.
#On average model 5 has the lowest training and validation loss. Model 5 Test Loss: 0.3609, Test Accuracy: 0.8508.
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.6702 - accuracy: 0.7835 - val_loss: 0.6519 - val_accuracy: 0.7869
# Epoch 2/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.6369 - accuracy: 0.7894 - val_loss: 0.6300 - val_accuracy: 0.7869
# Epoch 3/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.6078 - accuracy: 0.7894 - val_loss: 0.5943 - val_accuracy: 0.7869
# Epoch 4/30
# 3000/3000 [==============================] - 8s 3ms/step - loss: 0.5689 - accuracy: 0.7894 - val_loss: 0.5548 - val_accuracy: 0.7869
# Epoch 5/30
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.5317 - accuracy: 0.7894 - val_loss: 0.5215 - val_accuracy: 0.7874
# Epoch 6/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.5023 - accuracy: 0.8005 - val_loss: 0.4965 - val_accuracy: 0.8025
# Epoch 7/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4803 - accuracy: 0.8117 - val_loss: 0.4788 - val_accuracy: 0.8084
# Epoch 8/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4639 - accuracy: 0.8198 - val_loss: 0.4645 - val_accuracy: 0.8147
# Epoch 9/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4517 - accuracy: 0.8244 - val_loss: 0.4559 - val_accuracy: 0.8172
# Epoch 10/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4428 - accuracy: 0.8274 - val_loss: 0.4474 - val_accuracy: 0.8197
# Epoch 11/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4359 - accuracy: 0.8297 - val_loss: 0.4419 - val_accuracy: 0.8202
# Epoch 12/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4306 - accuracy: 0.8307 - val_loss: 0.4383 - val_accuracy: 0.8210
# Epoch 13/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4262 - accuracy: 0.8320 - val_loss: 0.4329 - val_accuracy: 0.8225
# Epoch 14/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4224 - accuracy: 0.8332 - val_loss: 0.4293 - val_accuracy: 0.8244
# Epoch 15/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4188 - accuracy: 0.8339 - val_loss: 0.4259 - val_accuracy: 0.8247
# Epoch 16/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4152 - accuracy: 0.8345 - val_loss: 0.4241 - val_accuracy: 0.8261
# Epoch 17/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4114 - accuracy: 0.8354 - val_loss: 0.4184 - val_accuracy: 0.8276
# Epoch 18/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4073 - accuracy: 0.8370 - val_loss: 0.4141 - val_accuracy: 0.8282
# Epoch 19/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4029 - accuracy: 0.8381 - val_loss: 0.4097 - val_accuracy: 0.8296
# Epoch 20/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3983 - accuracy: 0.8397 - val_loss: 0.4053 - val_accuracy: 0.8308
# Epoch 21/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3934 - accuracy: 0.8411 - val_loss: 0.3999 - val_accuracy: 0.8326
# Epoch 22/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3885 - accuracy: 0.8423 - val_loss: 0.3970 - val_accuracy: 0.8333
# Epoch 23/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3837 - accuracy: 0.8433 - val_loss: 0.3900 - val_accuracy: 0.8367
# Epoch 24/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3789 - accuracy: 0.8451 - val_loss: 0.3869 - val_accuracy: 0.8352
# Epoch 25/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3744 - accuracy: 0.8465 - val_loss: 0.3814 - val_accuracy: 0.8388
# Epoch 26/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3706 - accuracy: 0.8476 - val_loss: 0.3785 - val_accuracy: 0.8403
# Epoch 27/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3672 - accuracy: 0.8484 - val_loss: 0.3751 - val_accuracy: 0.8448
# Epoch 28/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3643 - accuracy: 0.8494 - val_loss: 0.3725 - val_accuracy: 0.8448
# Epoch 29/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3619 - accuracy: 0.8496 - val_loss: 0.3703 - val_accuracy: 0.8452
# Epoch 30/30
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.3597 - accuracy: 0.8511 - val_loss: 0.3685 - val_accuracy: 0.8478
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.6575 - accuracy: 0.7878 - val_loss: 0.6411 - val_accuracy: 0.7869
# Epoch 2/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.6212 - accuracy: 0.7894 - val_loss: 0.6121 - val_accuracy: 0.7869
# Epoch 3/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5883 - accuracy: 0.7894 - val_loss: 0.5772 - val_accuracy: 0.7869
# Epoch 4/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5535 - accuracy: 0.7894 - val_loss: 0.5437 - val_accuracy: 0.7869
# Epoch 5/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5238 - accuracy: 0.7915 - val_loss: 0.5189 - val_accuracy: 0.8019
# Epoch 6/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5015 - accuracy: 0.8063 - val_loss: 0.4997 - val_accuracy: 0.8036
# Epoch 7/30
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.4852 - accuracy: 0.8143 - val_loss: 0.4860 - val_accuracy: 0.8102
# Epoch 8/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4734 - accuracy: 0.8195 - val_loss: 0.4768 - val_accuracy: 0.8143
# Epoch 9/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4647 - accuracy: 0.8235 - val_loss: 0.4699 - val_accuracy: 0.8165
# Epoch 10/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4582 - accuracy: 0.8253 - val_loss: 0.4643 - val_accuracy: 0.8195
# Epoch 11/30
# 3000/3000 [==============================] - 8s 3ms/step - loss: 0.4529 - accuracy: 0.8274 - val_loss: 0.4612 - val_accuracy: 0.8198
# Epoch 12/30
# 3000/3000 [==============================] - 10s 3ms/step - loss: 0.4483 - accuracy: 0.8293 - val_loss: 0.4570 - val_accuracy: 0.8203
# Epoch 13/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4438 - accuracy: 0.8299 - val_loss: 0.4513 - val_accuracy: 0.8211
# Epoch 14/30
# 3000/3000 [==============================] - 10s 3ms/step - loss: 0.4391 - accuracy: 0.8313 - val_loss: 0.4469 - val_accuracy: 0.8215
# Epoch 15/30
# 3000/3000 [==============================] - 8s 3ms/step - loss: 0.4342 - accuracy: 0.8321 - val_loss: 0.4418 - val_accuracy: 0.8233
# Epoch 16/30
# 3000/3000 [==============================] - 8s 3ms/step - loss: 0.4287 - accuracy: 0.8328 - val_loss: 0.4359 - val_accuracy: 0.8240
# Epoch 17/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4231 - accuracy: 0.8343 - val_loss: 0.4328 - val_accuracy: 0.8239
# Epoch 18/30
# 3000/3000 [==============================] - 8s 3ms/step - loss: 0.4169 - accuracy: 0.8360 - val_loss: 0.4246 - val_accuracy: 0.8263
# Epoch 19/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4108 - accuracy: 0.8364 - val_loss: 0.4175 - val_accuracy: 0.8291
# Epoch 20/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4044 - accuracy: 0.8383 - val_loss: 0.4117 - val_accuracy: 0.8290
# Epoch 21/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3985 - accuracy: 0.8393 - val_loss: 0.4060 - val_accuracy: 0.8326
# Epoch 22/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3930 - accuracy: 0.8407 - val_loss: 0.4008 - val_accuracy: 0.8314
# Epoch 23/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3877 - accuracy: 0.8416 - val_loss: 0.3961 - val_accuracy: 0.8325
# Epoch 24/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3828 - accuracy: 0.8428 - val_loss: 0.3905 - val_accuracy: 0.8343
# Epoch 25/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3783 - accuracy: 0.8442 - val_loss: 0.3866 - val_accuracy: 0.8363
# Epoch 26/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3742 - accuracy: 0.8460 - val_loss: 0.3839 - val_accuracy: 0.8369
# Epoch 27/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3710 - accuracy: 0.8466 - val_loss: 0.3793 - val_accuracy: 0.8408
# Epoch 28/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3675 - accuracy: 0.8475 - val_loss: 0.3776 - val_accuracy: 0.8413
# Epoch 29/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3649 - accuracy: 0.8494 - val_loss: 0.3745 - val_accuracy: 0.8419
# Epoch 30/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3622 - accuracy: 0.8498 - val_loss: 0.3698 - val_accuracy: 0.8458
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.6586 - accuracy: 0.7891 - val_loss: 0.6469 - val_accuracy: 0.7869
# Epoch 2/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.6291 - accuracy: 0.7894 - val_loss: 0.6232 - val_accuracy: 0.7869
# Epoch 3/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5998 - accuracy: 0.7894 - val_loss: 0.5881 - val_accuracy: 0.7869
# Epoch 4/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.5631 - accuracy: 0.7894 - val_loss: 0.5515 - val_accuracy: 0.7869
# Epoch 5/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5291 - accuracy: 0.7895 - val_loss: 0.5209 - val_accuracy: 0.7875
# Epoch 6/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5024 - accuracy: 0.8013 - val_loss: 0.4975 - val_accuracy: 0.8035
# Epoch 7/30
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.4821 - accuracy: 0.8124 - val_loss: 0.4808 - val_accuracy: 0.8119
# Epoch 8/30
# 3000/3000 [==============================] - 8s 3ms/step - loss: 0.4668 - accuracy: 0.8206 - val_loss: 0.4680 - val_accuracy: 0.8151
# Epoch 9/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4547 - accuracy: 0.8252 - val_loss: 0.4580 - val_accuracy: 0.8201
# Epoch 10/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4446 - accuracy: 0.8299 - val_loss: 0.4489 - val_accuracy: 0.8214
# Epoch 11/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4360 - accuracy: 0.8316 - val_loss: 0.4404 - val_accuracy: 0.8238
# Epoch 12/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4279 - accuracy: 0.8338 - val_loss: 0.4324 - val_accuracy: 0.8245
# Epoch 13/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4199 - accuracy: 0.8351 - val_loss: 0.4260 - val_accuracy: 0.8253
# Epoch 14/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4125 - accuracy: 0.8368 - val_loss: 0.4179 - val_accuracy: 0.8271
# Epoch 15/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4052 - accuracy: 0.8383 - val_loss: 0.4126 - val_accuracy: 0.8287
# Epoch 16/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3985 - accuracy: 0.8398 - val_loss: 0.4059 - val_accuracy: 0.8287
# Epoch 17/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3924 - accuracy: 0.8409 - val_loss: 0.3995 - val_accuracy: 0.8324
# Epoch 18/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3866 - accuracy: 0.8423 - val_loss: 0.3942 - val_accuracy: 0.8333
# Epoch 19/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3813 - accuracy: 0.8448 - val_loss: 0.3881 - val_accuracy: 0.8366
# Epoch 20/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3765 - accuracy: 0.8457 - val_loss: 0.3874 - val_accuracy: 0.8359
# Epoch 21/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3723 - accuracy: 0.8471 - val_loss: 0.3796 - val_accuracy: 0.8413
# Epoch 22/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3685 - accuracy: 0.8482 - val_loss: 0.3764 - val_accuracy: 0.8423
# Epoch 23/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3652 - accuracy: 0.8489 - val_loss: 0.3741 - val_accuracy: 0.8422
# Epoch 24/30
# 3000/3000 [==============================] - 8s 3ms/step - loss: 0.3623 - accuracy: 0.8504 - val_loss: 0.3707 - val_accuracy: 0.8462
# Epoch 25/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3598 - accuracy: 0.8512 - val_loss: 0.3673 - val_accuracy: 0.8482
# Epoch 26/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3576 - accuracy: 0.8520 - val_loss: 0.3657 - val_accuracy: 0.8480
# Epoch 27/30
# 3000/3000 [==============================] - 5s 2ms/step - loss: 0.3553 - accuracy: 0.8525 - val_loss: 0.3625 - val_accuracy: 0.8493
# Epoch 28/30
# 3000/3000 [==============================] - 8s 3ms/step - loss: 0.3535 - accuracy: 0.8528 - val_loss: 0.3615 - val_accuracy: 0.8498
# Epoch 29/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3518 - accuracy: 0.8543 - val_loss: 0.3617 - val_accuracy: 0.8487
# Epoch 30/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3501 - accuracy: 0.8544 - val_loss: 0.3573 - val_accuracy: 0.8521
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.6596 - accuracy: 0.7879 - val_loss: 0.6433 - val_accuracy: 0.7869
# Epoch 2/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.6232 - accuracy: 0.7894 - val_loss: 0.6138 - val_accuracy: 0.7869
# Epoch 3/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5894 - accuracy: 0.7894 - val_loss: 0.5769 - val_accuracy: 0.7869
# Epoch 4/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5528 - accuracy: 0.7894 - val_loss: 0.5419 - val_accuracy: 0.7869
# Epoch 5/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5213 - accuracy: 0.7935 - val_loss: 0.5143 - val_accuracy: 0.7985
# Epoch 6/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4968 - accuracy: 0.8063 - val_loss: 0.4932 - val_accuracy: 0.8072
# Epoch 7/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4779 - accuracy: 0.8150 - val_loss: 0.4790 - val_accuracy: 0.8108
# Epoch 8/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4636 - accuracy: 0.8222 - val_loss: 0.4652 - val_accuracy: 0.8153
# Epoch 9/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4520 - accuracy: 0.8257 - val_loss: 0.4548 - val_accuracy: 0.8200
# Epoch 10/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4428 - accuracy: 0.8283 - val_loss: 0.4467 - val_accuracy: 0.8211
# Epoch 11/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4347 - accuracy: 0.8312 - val_loss: 0.4399 - val_accuracy: 0.8215
# Epoch 12/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4274 - accuracy: 0.8325 - val_loss: 0.4324 - val_accuracy: 0.8241
# Epoch 13/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4207 - accuracy: 0.8332 - val_loss: 0.4257 - val_accuracy: 0.8246
# Epoch 14/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4139 - accuracy: 0.8357 - val_loss: 0.4195 - val_accuracy: 0.8273
# Epoch 15/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4074 - accuracy: 0.8374 - val_loss: 0.4137 - val_accuracy: 0.8280
# Epoch 16/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4013 - accuracy: 0.8389 - val_loss: 0.4074 - val_accuracy: 0.8295
# Epoch 17/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3953 - accuracy: 0.8396 - val_loss: 0.4046 - val_accuracy: 0.8285
# Epoch 18/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3897 - accuracy: 0.8412 - val_loss: 0.3961 - val_accuracy: 0.8328
# Epoch 19/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3844 - accuracy: 0.8424 - val_loss: 0.3920 - val_accuracy: 0.8336
# Epoch 20/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3798 - accuracy: 0.8443 - val_loss: 0.3885 - val_accuracy: 0.8354
# Epoch 21/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3755 - accuracy: 0.8454 - val_loss: 0.3852 - val_accuracy: 0.8374
# Epoch 22/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3716 - accuracy: 0.8466 - val_loss: 0.3793 - val_accuracy: 0.8389
# Epoch 23/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3682 - accuracy: 0.8485 - val_loss: 0.3756 - val_accuracy: 0.8419
# Epoch 24/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3649 - accuracy: 0.8485 - val_loss: 0.3722 - val_accuracy: 0.8451
# Epoch 25/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3620 - accuracy: 0.8501 - val_loss: 0.3715 - val_accuracy: 0.8458
# Epoch 26/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3596 - accuracy: 0.8507 - val_loss: 0.3680 - val_accuracy: 0.8477
# Epoch 27/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3571 - accuracy: 0.8521 - val_loss: 0.3646 - val_accuracy: 0.8479
# Epoch 28/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3550 - accuracy: 0.8524 - val_loss: 0.3635 - val_accuracy: 0.8472
# Epoch 29/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3530 - accuracy: 0.8542 - val_loss: 0.3603 - val_accuracy: 0.8497
# Epoch 30/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3511 - accuracy: 0.8544 - val_loss: 0.3586 - val_accuracy: 0.8501
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.6537 - accuracy: 0.7890 - val_loss: 0.6402 - val_accuracy: 0.7869
# Epoch 2/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.6193 - accuracy: 0.7894 - val_loss: 0.6096 - val_accuracy: 0.7869
# Epoch 3/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5846 - accuracy: 0.7894 - val_loss: 0.5724 - val_accuracy: 0.7869
# Epoch 4/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.5477 - accuracy: 0.7894 - val_loss: 0.5371 - val_accuracy: 0.7869
# Epoch 5/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.5165 - accuracy: 0.7942 - val_loss: 0.5110 - val_accuracy: 0.7955
# Epoch 6/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4937 - accuracy: 0.8075 - val_loss: 0.4910 - val_accuracy: 0.8077
# Epoch 7/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4773 - accuracy: 0.8169 - val_loss: 0.4775 - val_accuracy: 0.8143
# Epoch 8/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4649 - accuracy: 0.8224 - val_loss: 0.4683 - val_accuracy: 0.8154
# Epoch 9/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4554 - accuracy: 0.8269 - val_loss: 0.4603 - val_accuracy: 0.8197
# Epoch 10/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4473 - accuracy: 0.8290 - val_loss: 0.4523 - val_accuracy: 0.8220
# Epoch 11/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4398 - accuracy: 0.8313 - val_loss: 0.4454 - val_accuracy: 0.8224
# Epoch 12/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4324 - accuracy: 0.8327 - val_loss: 0.4379 - val_accuracy: 0.8248
# Epoch 13/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4252 - accuracy: 0.8342 - val_loss: 0.4326 - val_accuracy: 0.8244
# Epoch 14/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.4178 - accuracy: 0.8355 - val_loss: 0.4234 - val_accuracy: 0.8271
# Epoch 15/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4107 - accuracy: 0.8369 - val_loss: 0.4167 - val_accuracy: 0.8276
# Epoch 16/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.4038 - accuracy: 0.8390 - val_loss: 0.4114 - val_accuracy: 0.8297
# Epoch 17/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3971 - accuracy: 0.8402 - val_loss: 0.4033 - val_accuracy: 0.8323
# Epoch 18/30
# 3000/3000 [==============================] - 8s 3ms/step - loss: 0.3910 - accuracy: 0.8412 - val_loss: 0.3978 - val_accuracy: 0.8329
# Epoch 19/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3855 - accuracy: 0.8435 - val_loss: 0.3931 - val_accuracy: 0.8338
# Epoch 20/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3803 - accuracy: 0.8450 - val_loss: 0.3881 - val_accuracy: 0.8384
# Epoch 21/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3758 - accuracy: 0.8458 - val_loss: 0.3845 - val_accuracy: 0.8379
# Epoch 22/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3719 - accuracy: 0.8469 - val_loss: 0.3799 - val_accuracy: 0.8388
# Epoch 23/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3684 - accuracy: 0.8479 - val_loss: 0.3758 - val_accuracy: 0.8429
# Epoch 24/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3654 - accuracy: 0.8489 - val_loss: 0.3730 - val_accuracy: 0.8449
# Epoch 25/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3626 - accuracy: 0.8505 - val_loss: 0.3706 - val_accuracy: 0.8454
# Epoch 26/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3601 - accuracy: 0.8500 - val_loss: 0.3685 - val_accuracy: 0.8469
# Epoch 27/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3579 - accuracy: 0.8508 - val_loss: 0.3670 - val_accuracy: 0.8459
# Epoch 28/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3559 - accuracy: 0.8520 - val_loss: 0.3636 - val_accuracy: 0.8480
# Epoch 29/30
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.3541 - accuracy: 0.8521 - val_loss: 0.3650 - val_accuracy: 0.8461
# Epoch 30/30
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.3524 - accuracy: 0.8533 - val_loss: 0.3609 - val_accuracy: 0.8493
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3590 - accuracy: 0.8499
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3685 - accuracy: 0.8478
# Model 1 (layers: 1, nodes: (16,))
# - Training Loss: 0.3590, Training Accuracy: 0.8499
# - Validation Loss: 0.3685, Validation Accuracy: 0.8478
#
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3602 - accuracy: 0.8505
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3698 - accuracy: 0.8458
# Model 2 (layers: 1, nodes: (64,))
# - Training Loss: 0.3602, Training Accuracy: 0.8505
# - Validation Loss: 0.3698, Validation Accuracy: 0.8458
#
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3489 - accuracy: 0.8552
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3573 - accuracy: 0.8521
# Model 3 (layers: 1, nodes: (128,))
# - Training Loss: 0.3489, Training Accuracy: 0.8552
# - Validation Loss: 0.3573, Validation Accuracy: 0.8521
#
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3497 - accuracy: 0.8545
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8501
# Model 4 (layers: 2, nodes: (128, 16))
# - Training Loss: 0.3497, Training Accuracy: 0.8545
# - Validation Loss: 0.3586, Validation Accuracy: 0.8501
#
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3511 - accuracy: 0.8543
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3609 - accuracy: 0.8493
# Model 5 (layers: 2, nodes: (128, 64))
# - Training Loss: 0.3511, Training Accuracy: 0.8543
# - Validation Loss: 0.3609, Validation Accuracy: 0.8493
#
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3609 - accuracy: 0.8508
# Test Loss: 0.3609, Test Accuracy: 0.8508
